# %%
import numpy as np 
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\saurabh\\Desktop\\pyth\\placement.csv")
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:3 , :4] 
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1

# %%
s = df.axes

# %%
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
df.shape
# Out:
# (100, 3)

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty   # check missing data 
b
# Out:
# False

# %%
i = df.ndim  # Check dimension of data
i
# Out:
# 2

# %%
d  = df.size   # row count * column count  = 100*3 = 300 
d
# Out:
# 300

# %%
a = df.values 
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'cgpa')
p
# Out:
#     cgpa  resume_score  placed
# 79  5.27          7.28       0
# 6   5.34          7.09       0
# 92  5.43          6.18       0
# 11  5.44          6.54       0
# 49  5.46          6.73       0
# ..   ...           ...     ...
# 34  8.87          7.19       1
# 15  8.88          5.93       1
# 37  9.05          8.21       1
# 93  9.31          7.39       1
# 76  9.40          5.50       1
#
# [100 rows x 3 columns]

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
p = df.sort_values(by = 'placed')
p
# Out:
#     cgpa  resume_score  placed
# 49  5.46          6.73       0
# 46  5.83          5.21       0
# 48  5.54          6.57       0
# 51  6.54          7.39       0
# 52  5.90          7.50       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 67  6.59          6.81       1
# 16  8.04          7.64       1
# 70  7.12          7.41       1
# 0   8.14          6.52       1
#
# [100 rows x 3 columns]

# %%
q = df.sort_values(by = ['cgpa' , 'resume_score'])
q
# Out:
#     cgpa  resume_score  placed
# 79  5.27          7.28       0
# 6   5.34          7.09       0
# 92  5.43          6.18       0
# 11  5.44          6.54       0
# 49  5.46          6.73       0
# ..   ...           ...     ...
# 34  8.87          7.19       1
# 15  8.88          5.93       1
# 37  9.05          8.21       1
# 93  9.31          7.39       1
# 76  9.40          5.50       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index() 
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(int)

# %%
df = df.astype(int) 
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
df = df.abs()   # absolute values ==> |-4| = 4 , |4| = 4 
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
# df = df['cgpa'].add(4) 
# df

# %%
s = df.count() 
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p  = df.cummax() 
p
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      8             6       1
# 2      8             8       1
# 3      8             8       1
# 4      8             8       1
# ..   ...           ...     ...
# 95     9             9       1
# 96     9             9       1
# 97     9             9       1
# 98     9             9       1
# 99     9             9       1
#
# [100 rows x 3 columns]

# %%
p = df.max() 
p
# Out:
# cgpa            9
# resume_score    9
# placed          1
# dtype: int32

# %%
q = df.min() 
q
# Out:
# cgpa            5
# resume_score    4
# placed          0
# dtype: int32

# %%
r = df.mean()   # x = 1,2,3 == > (1+2+3)/3 = 2(mean)
r
# Out:
# cgpa            6.47
# resume_score    6.47
# placed          0.50
# dtype: float64

# %%
s = df.median() # 
s
# Out:
# cgpa            6.0
# resume_score    7.0
# placed          0.5
# dtype: float64

# %%
# median () ==> total values => even => n/2+1 
# odd => (n/2+2)/2

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0      8             6       1
# 1      6             5       0
# 2      8             8       1
# 3      6             7       1
# 4      7             7       1
# ..   ...           ...     ...
# 95     6             6       0
# 96     8             7       1
# 97     6             7       0
# 98     8             5       1
# 99     6             6       0
#
# [100 rows x 3 columns]

# %%
e = df.filter(items = ['cgpa','placed']) 
e
# Out:
#     cgpa  placed
# 0      8       1
# 1      6       0
# 2      8       1
# 3      6       1
# 4      7       1
# ..   ...     ...
# 95     6       0
# 96     8       1
# 97     6       0
# 98     8       1
# 99     6       0
#
# [100 rows x 2 columns]

# %%
df[df['cgpa']>8]
# Out:
#     cgpa  resume_score  placed
# 37     9             8       1
# 76     9             5       1
# 93     9             7       1

# %%
p = df.rename(columns = {"cgpa":"college_marks" , 'resume_score':'semester_marks'}) 
p
# Out:
#     college_marks  semester_marks  placed
# 0               8               6       1
# 1               6               5       0
# 2               8               8       1
# 3               6               7       1
# 4               7               7       1
# ..            ...             ...     ...
# 95              6               6       0
# 96              8               7       1
# 97              6               7       0
# 98              8               5       1
# 99              6               6       0
#
# [100 rows x 3 columns]
